# %%
import pandas as pd

# %%
data=pd.read_csv("data/feature_clickstream.csv")
data.head()
# Out:
#    fe_1  fe_2  fe_3  fe_4  fe_5  fe_6  fe_7  fe_8  fe_9  fe_10  ...  fe_13  \
# 0    63   118    80   121    55   193   111   112  -101     83  ...    -16
# 1  -108   182   123     4   -56    27    25    -6   284    222  ...    -14
# 2   -13     8    87   166   214   -98   215   152   129    139  ...     26
# 3   -85    45   200    89   128    54    76    51    61    139  ...    172
# 4    55   120   226   -86   253    97   107    68   103    126  ...     76
#
#    fe_14  fe_15  fe_16  fe_17  fe_18  fe_19  fe_20  Customer_ID  snapshot_date
# 0    -81   -126    114     35     85    -73     76   CUS_0x1037     2023-01-01
# 1    -96    200     35    130     94    111     75   CUS_0x1069     2023-01-01
# 2     86    171    125   -130    354     17    302   CUS_0x114a     2023-01-01
# 3     96    174    163     37    207    180    118   CUS_0x1184     2023-01-01
# 4     43    183    159    -26    104    118    184   CUS_0x1297     2023-01-01
#
# [5 rows x 22 columns]

# %%
val_count=data["Customer_ID"].value_counts()
print(val_count)
# Out:
# Customer_ID
# CUS_0x1037    24
# CUS_0xa1ce    24
# CUS_0xa00f    24
# CUS_0xa014    24
# CUS_0xa022    24
#               ..
# CUS_0xa21c    24
# CUS_0xa20b    24
# CUS_0xa1cc    24
# CUS_0xa15a    24
# CUS_0xfe4     24
# Name: count, Length: 8974, dtype: int64

# %%
values=data[data["Customer_ID"]=="CUS_0x1037"]
print(values)
# Out:
#         fe_1  fe_2  fe_3  fe_4  fe_5  fe_6  fe_7  fe_8  fe_9  fe_10  ...  \
# 0         63   118    80   121    55   193   111   112  -101     83  ...
# 8974      55    96    74   171   -69  -103    86   178    42    113  ...
# 17948    232   203   -71    86   243    12    79   122   103    178  ...
# 26922      9   -29    -8   116   198    68    79    61   113     91  ...
# 35896    203    75   223    88   188   164    82    18   195     50  ...
# 44870    145   108    78   -33   212    62   -46   135    -6     96  ...
# 53844     40    90   231   136   239   273   106   178    90    202  ...
# 62818      2   128   115   -31   106   144    69   200    16    248  ...
# 71792    221   226  -112    49   226   209    44   123   244    106  ...
# 80766    168   176   119   190   151   -17   -17   -46   172     56  ...
# 89740     63   247   155    46    61   229   229   107   129    395  ...
# 98714    146   183    61   185   285   169   105   196   173    121  ...
# ...

# %%
data_1=pd.read_csv("data/features_attributes.csv")

print(data_1.shape)
val_count=data_1["Customer_ID"].value_counts()

print(val_count)
# Out:
# (12500, 6)
# Customer_ID
# CUS_0x1000    1
# CUS_0x8cfe    1
# CUS_0x8cbe    1
# CUS_0x8cc1    1
# CUS_0x8cc5    1
#              ..
# CUS_0x4f3b    1
# CUS_0x4f3e    1
# CUS_0x4f41    1
# CUS_0x4f43    1
# CUS_0xffd     1
# Name: count, Length: 12500, dtype: int64

# %%
data_2=pd.read_csv("data/features_financials.csv")
merge_result=pd.merge(data_2,data_1,on="Customer_ID",how="outer")
print(merge_result.head())
# Out:
#   Customer_ID       Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 0  CUS_0x1000            30625.94            2706.161667                  6
# 1  CUS_0x1009           52312.68_            4250.390000                  6
# 2  CUS_0x100b  113781.38999999998            9549.782500                  1
# 3  CUS_0x1011            58918.47            5208.872500                  3
# 4  CUS_0x1013            98620.98            7962.415000                  3
#
#    Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                5             27           2
# 1                5             17           4
# 2                4              1           0
# 3                3             17           3
# 4                3              6           3
#
#                                         Type_of_Loan  Delay_from_due_date  \
# 0          Credit-Builder Loan, and Home Equity Loan                   57
# 1  Not Specified, Home Equity Loan, Credit-Builde...                    5
# ...

# %%
merge_result.to_csv('test_data/attri_fina.csv',index=False)

# %%
rows,cols=merge_result.shape
merge_result.isnull().sum()
# Out:
# Customer_ID                    0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Num_Bank_Accounts              0
# Num_Credit_Card                0
# Interest_Rate                  0
# Num_of_Loan                    0
# Type_of_Loan                1426
# Delay_from_due_date            0
# Num_of_Delayed_Payment         0
# Changed_Credit_Limit           0
# Num_Credit_Inquiries           0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age             0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly        0
# Payment_Behaviour              0
# Monthly_Balance                0
# snapshot_date_x                0
# Name                           0
# Age                            0
# SSN                            0
# Occupation                     0
# snapshot_date_y                0
# dtype: int64

# %%
merge_result["Type_of_Loan"]=merge_result["Type_of_Loan"].fillna("unknown")

# %%
merge_result.isnull().sum()
# Out:
# Customer_ID                 0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# snapshot_date_x             0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# snapshot_date_y             0
# dtype: int64
